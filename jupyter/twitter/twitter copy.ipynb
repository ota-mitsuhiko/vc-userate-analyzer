# %%
import os
import tweepy
import pandas as pd
import numpy as np
from dotenv import load_dotenv
from sudachipy import tokenizer
from sudachipy import dictionary
from datetime import datetime

# %%
load_dotenv()
api_key = os.environ["TWITTER_API_KEY"]
api_secret = os.environ["TWITTER_API_SECRET"]
access_token = os.environ["TWITTER_API_ACCESS_TOKEN"]
access_token_secret = os.environ["TWITTER_API_ACCESS_TOKEN_SECRET"]
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
tokenizer_obj = dictionary.Dictionary(dict_type="full").create()

# %%
statuses = api.user_timeline(user_id="@kiryutantan", count=100)
statuses2 = api.user_timeline(user_id="@kiryutantan", count=100)

# %%
statuses_json_list = list(map(lambda x: x._json, statuses2))

# def convert_to_datetime(datetime_str):
#   tweet_datetime = datetime.strptime(datetime_str, '%a %b %d %H:%M:%S %z %Y')
#   return tweet_datetime

# for i in range(len(statuses_json_list)):
#   statuses_json_list[i]["created_at"] = convert_to_datetime(statuses_json_list[i]["created_at"])

status_df = pd.json_normalize(statuses_json_list)

a = status_df.created_at[0]

# %%
status_df.to_csv("pandas_test.csv")
status_df

# statuses_json_list_with_datetime = list(map(lambda x: x._json, statuses))

# def convert_to_datetime(datetime_str):
#   tweet_datetime = datetime.strptime(datetime_str, '%a %b %d %H:%M:%S %z %Y')
#   return tweet_datetime

# for i in range(len(statuses_json_list)):
#   statuses_json_list_with_datetime[i]["created_at"] = convert_to_datetime(
#       statuses_json_list_with_datetime[i]["created_at"])
# Out:
#                         created_at                   id               id_str  \
# 0   Tue Nov 16 09:34:37 +0000 2021  1460541807712866305  1460541807712866305
# 1   Tue Nov 16 07:50:21 +0000 2021  1460515569816330242  1460515569816330242
# 2   Tue Nov 16 06:04:25 +0000 2021  1460488910329442307  1460488910329442307
# 3   Tue Nov 16 04:33:09 +0000 2021  1460465941637046275  1460465941637046275
# 4   Tue Nov 16 04:20:25 +0000 2021  1460462738249945097  1460462738249945097
# ..                             ...                  ...                  ...
# 95  Fri Nov 12 02:44:41 +0000 2021  1458989093635776516  1458989093635776516
# 96  Fri Nov 12 02:32:10 +0000 2021  1458985946473394177  1458985946473394177
# 97  Fri Nov 12 02:11:05 +0000 2021  1458980640670453762  1458980640670453762
# 98  Fri Nov 12 01:11:37 +0000 2021  1458965671513976833  1458965671513976833
# 99  Fri Nov 12 01:11:34 +0000 2021  1458965660231340034  1458965660231340034
#
#                                                  text  truncated  \
# 0   RT @SidOgura: アルファロメオチーム、2022年ドライバーに周冠宇選手の起用を発...      False
# 1   RT @mymerrymay: スキップさんとKジローさんとお子様らんちに感謝 https:...      False
# 2                  @merry_fanza 泣くなよw\n大丈夫、いつでも俺はいるから      False
# 3   @merry_fanza なるほど？\nまあ関わり方は変わるけど、仕事は変わんないからこれか...      False
# 4         @merry_fanza あ！？聞いてたならコメントして！？\nしゃぶってねえし！！！      False
# ..                                                ...        ...
# 95                         ザウバーがピアストリ乗せるならめちゃくちゃ楽しみだな      False
# 96             RT @xxyui_hxx: https://t.co/oK81zRSJZR      False
# 97  Python仮想環境を丸一日間違えてたときの顔ーーーーーーーーーーーーーーーーーーーーーーー...      False
# 98  RT @FANZA_EROGE_DMM: 期間限定‼️11/30(火)16:59まで‼️\n...      False
# 99  RT @FANZA_EROGE_DMM: まとめ買い‼️11/30(火)16:59まで‼️\...      False
#
#                                                source  in_reply_to_status_id  \
# 0   <a href="http://twitter.com/download/iphone" r...                    NaN
# 1   <a href="http://twitter.com/download/iphone" r...                    NaN
# 2   <a href="http://twitter.com/download/iphone" r...           1.460489e+18
# 3   <a href="http://twitter.com/download/iphone" r...           1.460466e+18
# 4   <a href="http://twitter.com/download/iphone" r...           1.460462e+18
# ..                                                ...                    ...
# 95  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 96  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 97  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 98  <a href="http://twitter.com/download/iphone" r...                    NaN
# 99  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#    in_reply_to_status_id_str  in_reply_to_user_id in_reply_to_user_id_str  \
# 0                       None                  NaN                    None
# 1                       None                  NaN                    None
# 2        1460488627108990977         1.298268e+18     1298267752369545217
# 3        1460465545971585026         1.298268e+18     1298267752369545217
# 4        1460462386972794882         1.298268e+18     1298267752369545217
# ..                       ...                  ...                     ...
# 95                      None                  NaN                    None
# 96                      None                  NaN                    None
# 97                      None                  NaN                    None
# 98                      None                  NaN                    None
# 99                      None                  NaN                    None
#
#     ... retweeted_status.favorited retweeted_status.retweeted  \
# 0   ...                       True                       True
# 1   ...                      False                       True
# 2   ...                        NaN                        NaN
# 3   ...                        NaN                        NaN
# 4   ...                        NaN                        NaN
# ..  ...                        ...                        ...
# 95  ...                        NaN                        NaN
# 96  ...                      False                       True
# 97  ...                        NaN                        NaN
# 98  ...                      False                       True
# 99  ...                      False                       True
#
#    retweeted_status.possibly_sensitive retweeted_status.lang  \
# 0                                False                    ja
# 1                                False                    ja
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
# ..                                 ...                   ...
# 95                                 NaN                   NaN
# 96                               False                   und
# 97                                 NaN                   NaN
# 98                                True                    ja
# 99                                True                    ja
#
#    possibly_sensitive                                     entities.media  \
# 0                 NaN                                                NaN
# 1               False  [{'id': 1460253855250530304, 'id_str': '146025...
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ..                ...                                                ...
# 95                NaN                                                NaN
# 96              False  [{'id': 1458843244083953664, 'id_str': '145884...
# 97                NaN                                                NaN
# 98                NaN                                                NaN
# 99                NaN                                                NaN
#
#                               extended_entities.media  \
# 0                                                 NaN
# 1   [{'id': 1460253855250530304, 'id_str': '146025...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  [{'id': 1458843244083953664, 'id_str': '145884...
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                       retweeted_status.entities.media  \
# 0                                                 NaN
# 1   [{'id': 1460253855250530304, 'id_str': '146025...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  [{'id': 1458843244083953664, 'id_str': '145884...
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#              retweeted_status.extended_entities.media  \
# 0                                                 NaN
# 1   [{'id': 1460253855250530304, 'id_str': '146025...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96  [{'id': 1458843244083953664, 'id_str': '145884...
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     retweeted_status.quoted_status.user.entities.url.urls
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 218 columns]
